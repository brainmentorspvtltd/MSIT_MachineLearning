# %%
import pandas as pd

# %%
matches = pd.read_csv("dataset/ipl/matches.csv", index_col='id')
#matches.set_index('id', inplace=True)

# %%
matches.shape
# Out:
# (756, 17)

# %%
matches.head()
# Out:
#     season       city        date                        team1  \
# id
# 1     2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2     2017       Pune  2017-04-06               Mumbai Indians
# 3     2017     Rajkot  2017-04-07                Gujarat Lions
# 4     2017     Indore  2017-04-08       Rising Pune Supergiant
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4               Kings XI Punjab              Kings XI Punjab         field
# 5              Delhi Daredevils  Royal Challengers Bangalore           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# id
# ...

# %%
matches.columns
# Out:
# Index(['season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
pd.value_counts( matches["season"] )
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
pd.value_counts(matches["winner"])
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
new_df = matches.drop_duplicates('season', keep='last')

# %%
new_df["winner"]
# Out:
# id
# 59              Mumbai Indians
# 117           Rajasthan Royals
# 174            Deccan Chargers
# 234        Chennai Super Kings
# 307        Chennai Super Kings
# 381      Kolkata Knight Riders
# 457             Mumbai Indians
# 517      Kolkata Knight Riders
# 576             Mumbai Indians
# 636        Sunrisers Hyderabad
# 7953       Chennai Super Kings
# 11415           Mumbai Indians
# Name: winner, dtype: object

# %%
new_df[["season", "winner"]]
# Out:
#        season                 winner
# id
# 59       2017         Mumbai Indians
# 117      2008       Rajasthan Royals
# 174      2009        Deccan Chargers
# 234      2010    Chennai Super Kings
# 307      2011    Chennai Super Kings
# 381      2012  Kolkata Knight Riders
# 457      2013         Mumbai Indians
# 517      2014  Kolkata Knight Riders
# 576      2015         Mumbai Indians
# 636      2016    Sunrisers Hyderabad
# 7953     2018    Chennai Super Kings
# 11415    2019         Mumbai Indians

# %%
matches[116:117]
# Out:
#      season    city        date                team1             team2  \
# id
# 117    2008  Mumbai  2008-06-01  Chennai Super Kings  Rajasthan Royals
#
#           toss_winner toss_decision  result  dl_applied            winner  \
# id
# 117  Rajasthan Royals         field  normal           0  Rajasthan Royals
#
#      win_by_runs  win_by_wickets player_of_match                       venue  \
# id
# 117            0               3       YK Pathan  Dr DY Patil Sports Academy
#
#        umpire1      umpire2 umpire3
# id
# 117  BF Bowden  RE Koertzen     NaN

# %%
matches.drop_duplicates('season', keep='last')[["season", "winner"]]
# Out:
#        season                 winner
# id
# 59       2017         Mumbai Indians
# 117      2008       Rajasthan Royals
# 174      2009        Deccan Chargers
# 234      2010    Chennai Super Kings
# 307      2011    Chennai Super Kings
# 381      2012  Kolkata Knight Riders
# 457      2013         Mumbai Indians
# 517      2014  Kolkata Knight Riders
# 576      2015         Mumbai Indians
# 636      2016    Sunrisers Hyderabad
# 7953     2018    Chennai Super Kings
# 11415    2019         Mumbai Indians

# %%
matches[ (matches["winner"] == "Chennai Super Kings") &
        (matches["win_by_runs"] > 50 ) ] [[ "team1", "team2", "win_by_runs" ]]
# Out:
#                      team1                        team2  win_by_runs
# id
# 122    Chennai Super Kings  Royal Challengers Bangalore           92
# 144    Chennai Super Kings              Deccan Chargers           78
# 182    Chennai Super Kings        Kolkata Knight Riders           55
# 285    Chennai Super Kings             Rajasthan Royals           63
# 307    Chennai Super Kings  Royal Challengers Bangalore           58
# 313    Chennai Super Kings              Deccan Chargers           74
# 380    Chennai Super Kings             Delhi Daredevils           86
# 404    Chennai Super Kings             Delhi Daredevils           86
# 435    Chennai Super Kings          Sunrisers Hyderabad           77
# 465    Chennai Super Kings             Delhi Daredevils           93
# 542    Chennai Super Kings              Kings XI Punjab           97
# 7910   Chennai Super Kings             Rajasthan Royals           64
# 11341  Chennai Super Kings               Delhi Capitals           80

# %%
pd.DataFrame( pd.value_counts( matches['player_of_match'] ).head() )
# Out:
#                 player_of_match
# CH Gayle                     21
# AB de Villiers               20
# RG Sharma                    17
# MS Dhoni                     17
# DA Warner                    17

# %%
deliveries = pd.read_csv("dataset/ipl/deliveries.csv")

# %%
deliveries.shape
# Out:
# (179078, 21)

# %%
deliveries.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  bye_runs  \
# ...

# %%
deliveries.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
# find player who took most number of catches
pd.value_counts(deliveries["dismissal_kind"])
# Out:
# caught                   5348
# bowled                   1581
# run out                   852
# lbw                       540
# stumped                   278
# caught and bowled         211
# retired hurt               12
# hit wicket                 10
# obstructing the field       2
# Name: dismissal_kind, dtype: int64

# %%
new_df = deliveries[ deliveries["dismissal_kind"] == "caught" ]

# %%
new_df
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 165            1       2  Royal Challengers Bangalore
# 206            1       2  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 178908     11415       1               Mumbai Indians
# 178921     11415       1               Mumbai Indians
# 178945     11415       1               Mumbai Indians
# 179019     11415       2          Chennai Super Kings
# 179067     11415       2          Chennai Super Kings
#
#                        bowling_team  over  ball       batsman   non_striker  \
# 11      Royal Challengers Bangalore     2     5     DA Warner      S Dhawan
# 64      Royal Challengers Bangalore    11     3      S Dhawan  MC Henriques
# 94      Royal Challengers Bangalore    16     2  MC Henriques  Yuvraj Singh
# ...

# %%
pd.value_counts( new_df["fielder"] )
# Out:
# KD Karthik             109
# SK Raina                99
# MS Dhoni                98
# AB de Villiers          93
# RV Uthappa              84
#                       ...
# B Stanlake               1
# AC Voges                 1
# R Vinay Kumar (sub)      1
# NJ Maddinson             1
# UBT Chand (sub)          1
# Name: fielder, Length: 491, dtype: int64

# %%
# which player has taken max wickets

# %%
deliveries[ deliveries['dismissal_kind'] == "bowled" ]
# Out:
#         match_id  inning                 batting_team  \
# 116            1       1          Sunrisers Hyderabad
# 160            1       2  Royal Challengers Bangalore
# 235            1       2  Royal Challengers Bangalore
# 274            2       1               Mumbai Indians
# 287            2       1               Mumbai Indians
# ...          ...     ...                          ...
# 178437     11413       1          Sunrisers Hyderabad
# 178700     11414       1               Delhi Capitals
# 178710     11414       1               Delhi Capitals
# 178811     11414       2          Chennai Super Kings
# 178901     11415       1               Mumbai Indians
#
#                        bowling_team  over  ball        batsman   non_striker  \
# 116     Royal Challengers Bangalore    19     4   Yuvraj Singh      DJ Hooda
# 160             Sunrisers Hyderabad     6     4  Mandeep Singh      CH Gayle
# 235             Sunrisers Hyderabad    18     4      S Aravind      TS Mills
# ...

# %%
temp_df = deliveries.dropna()

# %%
temp_df
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 165            1       2  Royal Challengers Bangalore
# 199            1       2  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 178977     11415       2          Chennai Super Kings
# 179019     11415       2          Chennai Super Kings
# 179033     11415       2          Chennai Super Kings
# 179067     11415       2          Chennai Super Kings
# 179075     11415       2          Chennai Super Kings
#
#                        bowling_team  over  ball       batsman   non_striker  \
# 11      Royal Challengers Bangalore     2     5     DA Warner      S Dhawan
# 64      Royal Challengers Bangalore    11     3      S Dhawan  MC Henriques
# 94      Royal Challengers Bangalore    16     2  MC Henriques  Yuvraj Singh
# ...

# %%
temp_df = deliveries[["bowler", "dismissal_kind"]]

# %%
temp_df = temp_df.dropna()

# %%
temp_df
# Out:
#              bowler dismissal_kind
# 11      A Choudhary         caught
# 64        STR Binny         caught
# 94        YS Chahal         caught
# 116        TS Mills         bowled
# 160     Rashid Khan         bowled
# ...             ...            ...
# 179019    JJ Bumrah         caught
# 179033    HH Pandya        run out
# 179067    JJ Bumrah         caught
# 179075   SL Malinga        run out
# 179077   SL Malinga            lbw
#
# [8834 rows x 2 columns]

# %%
pd.value_counts(temp_df["dismissal_kind"])
# Out:
# caught                   5348
# bowled                   1581
# run out                   852
# lbw                       540
# stumped                   278
# caught and bowled         211
# retired hurt               12
# hit wicket                 10
# obstructing the field       2
# Name: dismissal_kind, dtype: int64

# %%
(temp_df["dismissal_kind"] != "run out") & \
    (temp_df["dismissal_kind"] != "retired hurt") & \
        (temp_df["dismissal_kind"] != "obstructing the field")
# Out:
# 11         True
# 64         True
# 94         True
# 116        True
# 160        True
#           ...
# 179019     True
# 179033    False
# 179067     True
# 179075    False
# 179077     True
# Name: dismissal_kind, Length: 8834, dtype: bool

# %%
temp_df = temp_df[ (temp_df["dismissal_kind"] != "run out") & 
        (temp_df["dismissal_kind"] != "retired hurt") & 
        (temp_df["dismissal_kind"] != "obstructing the field") ]
pd.value_counts(temp_df["bowler"])
# Out:
# SL Malinga         170
# A Mishra           156
# Harbhajan Singh    150
# PP Chawla          149
# DJ Bravo           147
#                   ...
# S Vidyut             1
# S Rutherford         1
# D Short              1
# GR Napier            1
# AJ Finch             1
# Name: bowler, Length: 348, dtype: int64

# %%
deliveries.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
'''
import numpy as np
>>> x = np.random.randint(10, 1000, 40)
>>> x
array([302,  74,  95, 613, 895, 439, 927, 488, 653, 248,  89, 920, 318,
       628, 520, 428, 546, 401, 374, 643, 249, 766, 702, 661,  24, 170,
       279, 105, 636, 395, 156, 298, 597, 630, 203,  67, 889, 182, 777,
       129])
>>> y = x ** 2
>>> y
array([ 91204,   5476,   9025, 375769, 801025, 192721, 859329, 238144,
       426409,  61504,   7921, 846400, 101124, 394384, 270400, 183184,
       298116, 160801, 139876, 413449,  62001, 586756, 492804, 436921,
          576,  28900,  77841,  11025, 404496, 156025,  24336,  88804,
       356409, 396900,  41209,   4489, 790321,  33124, 603729,  16641])
>>> import matplotlib.pyplot as plt
>>> plt.plot(x,y)
[<matplotlib.lines.Line2D object at 0x11a37c278>]
>>> plt.show()
>>> x = arange(10,1000,40)
Traceback (most recent call last):
  File "<pyshell#8>", line 1, in <module>
    x = arange(10,1000,40)
NameError: name 'arange' is not defined
>>> x = np.arange(10,1000,40)
>>> x
array([ 10,  50,  90, 130, 170, 210, 250, 290, 330, 370, 410, 450, 490,
       530, 570, 610, 650, 690, 730, 770, 810, 850, 890, 930, 970])
>>> y = x ** 2
>>> y
array([   100,   2500,   8100,  16900,  28900,  44100,  62500,  84100,
       108900, 136900, 168100, 202500, 240100, 280900, 324900, 372100,
       422500, 476100, 532900, 592900, 656100, 722500, 792100, 864900,
       940900])
>>> plt.plot(x,y)
[<matplotlib.lines.Line2D object at 0x11daa44a8>]
>>> plt.show()
>>> x = np.random.randint(10, 1000, 40)
>>> x = np.random.randint(5, 200, 40)
>>> x = np.random.randint(10, 1000, 40)
>>> y = np.random.randint(5, 200, 40)
>>> x
array([705, 361, 532, 258,  70, 378, 848, 712, 626, 110, 851, 977, 397,
       882, 556, 224,  88, 171, 517, 779, 899, 215, 152, 551, 701, 921,
       467, 238,  62, 236, 295, 569, 823, 284, 979, 762, 116, 916, 325,
       926])
>>> y
array([127,  38, 136,  31, 114,   5,  53, 120,  49,  41, 153, 115,  11,
       185,  96,  30, 118,  63,  18,  19, 111, 102, 149, 149, 165, 108,
        27,  21, 104,  68, 110, 123,  30, 130, 149, 182,  11,  98, 151,
        64])
>>> plt.plot(x,y)
[<matplotlib.lines.Line2D object at 0x12177eac8>]
>>> plt.show()
>>> plt.plot(x,y,'o')
[<matplotlib.lines.Line2D object at 0x120a000f0>]
>>> plt.show()
'''
